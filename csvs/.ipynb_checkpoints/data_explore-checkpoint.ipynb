# %%
import pandas as pd

# %%
ls
# Out:
# Inspections.csv  Inventroy.csv    Untitled.ipynb   violations.csv

# %%
pd.read_csv('Inspections.csv').head(5)
# Out:
#   ACTIVITY DATE   OWNER ID   OWNER NAME FACILITY ID  FACILITY NAME  RECORD ID  \
# 0    08/23/2018  OW0000809           31   FA0019645  DREAM DINNERS  PR0045642
# 1    12/06/2017  OW0000809           31   FA0019645  DREAM DINNERS  PR0045642
# 2    06/23/2017  OW0000809           31   FA0019645  DREAM DINNERS  PR0045642
# 3    03/19/2019  OW0000809           31   FA0019645  DREAM DINNERS  PR0045642
# 4    03/01/2018  OW0000002  #1 CAFE INC   FA0056432        #1 CAFE  PR0045100
#
#     PROGRAM NAME PROGRAM STATUS  PROGRAM ELEMENT (PE)  \
# 0  DREAM DINNERS         ACTIVE                  1631
# 1  DREAM DINNERS         ACTIVE                  1631
# 2  DREAM DINNERS         ACTIVE                  1631
# 3  DREAM DINNERS         ACTIVE                  1631
# 4        #1 CAFE         ACTIVE                  1632
#
#                           PE DESCRIPTION  ... SERVICE DESCRIPTION SCORE GRADE  \
# 0  RESTAURANT (0-30) SEATS MODERATE RISK  ...  ROUTINE INSPECTION  97.0     A
# 1  RESTAURANT (0-30) SEATS MODERATE RISK  ...  ROUTINE INSPECTION  95.0     A
# 2  RESTAURANT (0-30) SEATS MODERATE RISK  ...  ROUTINE INSPECTION  96.0     A
# 3  RESTAURANT (0-30) SEATS MODERATE RISK  ...  ROUTINE INSPECTION  96.0     A
# 4      RESTAURANT (0-30) SEATS HIGH RISK  ...  ROUTINE INSPECTION  90.0     A
#
#   SERIAL NUMBER  EMPLOYEE ID                       Location  \
# 0     DA2FXQNN6    EE0000126   POINT (-118.36927 33.826754)
# 1     DACP43IQW    EE0000126   POINT (-118.36927 33.826754)
# 2     DAEMVMRBY    EE0000126   POINT (-118.36927 33.826754)
# 3     DANER68S4    EE0000126   POINT (-118.36927 33.826754)
# 4     DACZXQ74W    EE0000015  POINT (-118.412323 34.058815)
#
#    2011 Supervisorial District Boundaries (Official) Census Tracts 2010  \
# 0                                                4.0              820.0
# 1                                                4.0              820.0
# 2                                                4.0              820.0
# 3                                                4.0              820.0
# 4                                                3.0              660.0
#
#   Board Approved Statistical Areas Zip Codes
# 0                            102.0   25719.0
# 1                            102.0   25719.0
# 2                            102.0   25719.0
# 3                            102.0   25719.0
# 4                            265.0   24032.0
#
# [5 rows x 25 columns]

# %%
len(pd.read_csv('Inspections.csv')['Zip Codes'].unique())
# Out:
# 282

# %%
pd.read_csv('Inspections.csv').columns
# Out:
# Index(['ACTIVITY DATE', 'OWNER ID', 'OWNER NAME', 'FACILITY ID',
#        'FACILITY NAME', 'RECORD ID', 'PROGRAM NAME', 'PROGRAM STATUS',
#        'PROGRAM ELEMENT (PE)', 'PE DESCRIPTION', 'FACILITY ADDRESS',
#        'FACILITY CITY', 'FACILITY STATE', 'FACILITY ZIP', 'SERVICE CODE',
#        'SERVICE DESCRIPTION', 'SCORE', 'GRADE', 'SERIAL NUMBER', 'EMPLOYEE ID',
#        'Location', '2011 Supervisorial District Boundaries (Official)',
#        'Census Tracts 2010', 'Board Approved Statistical Areas', 'Zip Codes'],
#       dtype='object')

# %%
pd.read_csv('Inventroy.csv').head(5)
# Out:
#   FACILITY ID    FACILITY NAME  RECORD ID     PROGRAM NAME  \
# 0   FA0019645    DREAM DINNERS  PR0045642    DREAM DINNERS
# 1   FA0056432          #1 CAFE  PR0045100          #1 CAFE
# 2   FA0241857    LAUREL TAVERN  PR0189987    LAUREL TAVERN
# 3   FA0262822  10 SPEED COFFEE  PR0213623  10 SPEED COFFEE
# 4   FA0158893           10 - E  PR0146972           10 - E
#
#    PROGRAM ELEMENT (PE)                         PE DESCRIPTION  \
# 0                  1631  RESTAURANT (0-30) SEATS MODERATE RISK
# 1                  1632      RESTAURANT (0-30) SEATS HIGH RISK
# 2                  1638    RESTAURANT (61-150) SEATS HIGH RISK
# 3                  1631  RESTAURANT (0-30) SEATS MODERATE RISK
# 4                  1638    RESTAURANT (61-150) SEATS HIGH RISK
#
#                     FACILITY ADDRESS      FACILITY CITY FACILITY  STATE  \
# 0            22226 PALOS VERDES BLVD           TORRANCE              CA
# 1        2080 CENTURY PARK E STE 108        LOS ANGELES              CA
# 2                   1220 HERMOSA AVE      HERMOSA BEACH              CA
# 3  1919 SANTA&#160;MONICA BLVD # 102  SANTA&#160;MONICA              CA
# 4                       811 W 7TH ST        LOS ANGELES              CA
#
#   FACILITY ZIP  ...               OWNER NAME  \
# 0        90505  ...                       31
# 1        90067  ...              #1 CAFE INC
# 2        90254  ...  10 RIVERSIDE DRIVE, LLC
# 3        90404  ...    10 SPEED COFFEE, INC.
# 4        90017  ...                 10-E LLC
#
#                        OWNER ADDRESS         OWNER CITY OWNER STATE OWNER ZIP  \
# 0            22226   PALOS VERDES BL           TORRANCE          CA     90505
# 1          2080 CENTURY PARK E # 108        LOS ANGELES          CA     90067
# 2                   1220 HERMOSA AVE      HERMOSA BEACH          CA     90254
# 3  1919 SANTA&#160;MONICA BLVD # 102  SANTA&#160;MONICA          CA     90404
# 4                       811 W 7TH ST        LOS ANGELES          CA     90017
#
#                            Location Census Tracts 2010  \
# 0  (33.8261519457, -118.3688319755)              820.0
# 1  (34.0587577891, -118.4121459614)              660.0
# 2  (33.8624779341, -118.3999885065)              648.0
# 3  (34.0284451418, -118.4803289778)              441.0
# 4    (34.0490811348, -118.25910644)              709.0
#
#   2011 Supervisorial District Boundaries (Official)  \
# 0                                               4.0
# 1                                               3.0
# 2                                               4.0
# 3                                               3.0
# 4                                               1.0
#
#   Board Approved Statistical Areas  Zip Codes
# 0                            102.0    25719.0
# 1                            265.0    24032.0
# 2                            310.0    24688.0
# 3                             93.0    25713.0
# 4                            343.0    23078.0
#
# [5 rows x 23 columns]

# %%
pd.read_csv('Inventroy.csv').columns
# Out:
# Index(['FACILITY ID', 'FACILITY NAME', 'RECORD ID', ' PROGRAM NAME',
#        'PROGRAM ELEMENT (PE)', 'PE DESCRIPTION', 'FACILITY ADDRESS',
#        'FACILITY CITY', 'FACILITY  STATE', 'FACILITY ZIP', 'FACILITY LATITUDE',
#        'FACILITY LONGITUDE', 'OWNER ID', 'OWNER NAME', 'OWNER ADDRESS',
#        'OWNER CITY', 'OWNER STATE', 'OWNER ZIP', 'Location',
#        'Census Tracts 2010',
#        '2011 Supervisorial District Boundaries (Official)',
#        'Board Approved Statistical Areas', 'Zip Codes'],
#       dtype='object')

# %%
pd.read_csv('violations.csv')
# Out:
#        SERIAL NUMBER  VIOLATION  STATUS VIOLATION CODE  \
# 0          DA0004KIJ  OUT OF COMPLIANCE           F049
# 1          DA0004KIJ  OUT OF COMPLIANCE           F042
# 2          DA0004KIJ  OUT OF COMPLIANCE           F037
# 3          DA0004KIJ  OUT OF COMPLIANCE           F015
# 4          DA0004KIJ  OUT OF COMPLIANCE           F006
# ...              ...                ...            ...
# 954076     DAZZZA0P5  OUT OF COMPLIANCE           F034
# 954077     DAZZZA0P5  OUT OF COMPLIANCE           F030
# 954078     DAZZZA0P5  OUT OF COMPLIANCE           F024
# 954079     DAZZZIUVR  OUT OF COMPLIANCE           F035
# 954080     DAZZZIUVR  OUT OF COMPLIANCE           F034
#
#                                     VIOLATION DESCRIPTION  POINTS
# 0       # 50. Impoundment of unsanitary equipment or food       0
# 1       # 42. Toilet facilities: properly constructed,...       1
# 2       # 37. Adequate ventilation and lighting; desig...       1
# 3                # 15. Food obtained from approved source       2
# 4       # 06. Adequate handwashing facilities supplied...       2
# ...                                                   ...     ...
# 954076  # 34. Warewashing facilities: Adequate, mainta...       1
# 954077  # 30. Food properly stored; food storage conta...       1
# 954078  # 24. Person in charge present and performs du...       1
# 954079  # 35. Equipment/Utensils - approved; installed...       1
# 954080  # 34. Warewashing facilities: Adequate, mainta...       1
#
# [954081 rows x 5 columns]

# %%
'''Outputs should not include any data from vendors that have a ‘PROGRAM
STATUS’ of INACTIVE.'''

inspections_sample = pd.read_csv('Inspections.csv').head(100)
inspections_sample[~inspections_sample['PROGRAM STATUS'] == "INACTIVE"]
# Out:
#    ACTIVITY DATE   OWNER ID       OWNER NAME FACILITY ID    FACILITY NAME  \
# 9     03/29/2017  OW0000010     1 EVEN, INC.   FA0015045      CHO MAN WON
# 10    10/04/2016  OW0000010     1 EVEN, INC.   FA0015045      CHO MAN WON
# 11    02/15/2018  OW0000010     1 EVEN, INC.   FA0015045      CHO MAN WON
# 12    11/15/2017  OW0000010     1 EVEN, INC.   FA0015045      CHO MAN WON
# 69    09/21/2016  OW0000028  101 GINSENG INC   FA0002829  101 GINSENG UNC
# 70    04/24/2018  OW0000028  101 GINSENG INC   FA0002829  101 GINSENG UNC
#
#     RECORD ID     PROGRAM NAME PROGRAM STATUS  PROGRAM ELEMENT (PE)  \
# 9   PR0021365      CHO MAN WON       INACTIVE                  1635
# 10  PR0021365      CHO MAN WON       INACTIVE                  1635
# 11  PR0021365      CHO MAN WON       INACTIVE                  1635
# 12  PR0021365      CHO MAN WON       INACTIVE                  1635
# 69  PR0018827  101 GINSENG UNC       INACTIVE                  1613
# 70  PR0018827  101 GINSENG UNC       INACTIVE                  1613
#
#                           PE DESCRIPTION  ... SERVICE DESCRIPTION SCORE GRADE  \
# 9     RESTAURANT (31-60) SEATS HIGH RISK  ...  ROUTINE INSPECTION  90.0     A
# 10    RESTAURANT (31-60) SEATS HIGH RISK  ...  ROUTINE INSPECTION  90.0     A
# 11    RESTAURANT (31-60) SEATS HIGH RISK  ...  ROUTINE INSPECTION  90.0     A
# 12    RESTAURANT (31-60) SEATS HIGH RISK  ...  ROUTINE INSPECTION  81.0     B
# 69  FOOD MKT RETAIL (2,000+ SF) LOW RISK  ...  ROUTINE INSPECTION  96.0     A
# 70  FOOD MKT RETAIL (2,000+ SF) LOW RISK  ...  ROUTINE INSPECTION  96.0     A
#
#    SERIAL NUMBER  EMPLOYEE ID                       Location  \
# 9      DA8Y73IIR    EE0000884  POINT (-118.297235 34.052627)
# 10     DADY97Z7X    EE0000884  POINT (-118.297235 34.052627)
# 11     DASMTGAQ1    EE0000884  POINT (-118.297235 34.052627)
# 12     DAYKEKRUP    EE0000884  POINT (-118.297235 34.052627)
# 69     DAL0V7YQG    EE0000821   POINT (-118.12242 34.062576)
# 70     DAVNFSP1V    EE0000821   POINT (-118.12242 34.062576)
#
#     2011 Supervisorial District Boundaries (Official) Census Tracts 2010  \
# 9                                                 2.0             1003.0
# 10                                                2.0             1003.0
# 11                                                2.0             1003.0
# 12                                                2.0             1003.0
# 69                                                1.0             1842.0
# 70                                                1.0             1842.0
#
#    Board Approved Statistical Areas Zip Codes
# 9                             372.0   22723.0
# 10                            372.0   22723.0
# 11                            372.0   22723.0
# 12                            372.0   22723.0
# 69                             75.0    9730.0
# 70                             75.0    9730.0
#
# [6 rows x 25 columns]

# %%
'''
2. The ‘PE DESCRIPTION’ column contains information on the number and type of
seating available at the vendor. Extract this out into a new column, retain all
other information within that column. E.g.:
a. ‘FOOD MKT RETAIL (1-1,999 SF) LOW RISK’,
b. ‘RESTAURANT (61-150) SEATS LOW RISK’.
c. Extract the greyed area out and retain the rest in the examples
d. The client initially needs information to generate the following and output
the results using appropriate representation:'''
import re 

# extract content inside parantheses
in_paran = lambda x: re.search(r'\((.*?)\)',x).group(1)
inspections_sample['in_paran'] = inspections_sample['PE DESCRIPTION'].apply(in_paran)
# extract content outside parantheses
no_paran = lambda x: " ".join(re.findall(r"(.*?)(?:\(.*?\)|$)", x))
inspections_sample['no_paran'] = inspections_sample['PE DESCRIPTION'].apply(no_paran)

# %%
# 3. Produce the mean, mode and median for the inspection score per year:
#a. For each type of vendor’s seating
# b. For each ‘zip code’

from dateutil.parser import parse
import numpy as np
from scipy import stats

#create year column
inspections_sample['year'] = inspections_sample['ACTIVITY DATE'].apply(lambda x: parse(x, fuzzy=True).year)
# inspections_sample.pivot_table(index = 'in_paran', columns = 'year', values = 'SCORE', aggfunc = np.mean )

def pivot(index, columns, values, aggfunc, table):
    return table.pivot_table(index = index, 
                               columns = columns, 
                               values = values, 
                               aggfunc = aggfunc )

mode = lambda x: stats.mode(x)[0][0]
mode_table_seating = pivot('in_paran','year','SCORE', mode, inspections_sample)
mean_table_seating = pivot('in_paran','year','SCORE', np.mean, inspections_sample)
median_table_seating = pivot('in_paran','year','SCORE', np.median, inspections_sample)

mode_table_zip = pivot('Zip Codes','year','SCORE', mode, inspections_sample)

# %%
'''
Produce a suitable graph that displays the number of establishments that have
committed each type of violation, you may need to consider how you group this
data to make visualisation feasible
'''
violations = pd.read_csv("violations.csv")
merger = pd.merge(inspections_sample, violations, how='inner', on='SERIAL NUMBER')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
violations = merger.groupby('VIOLATION DESCRIPTION')['FACILITY NAME'].nunique()
fig = plt.figure(figsize = (10, 5))
x = np.arange(len(violations.index))
plt.xticks(x, violations.index, rotation='vertical')
plt.bar(violations.index, violations.values)
# Out:
# <BarContainer object of 38 artists>

# %%
'''
5. Determine if there is any significant correlation between the number of violations
committed per vendor and their zip code, ‘Is there a tendency for facilities in
specific locations to have more violations?’. You will need to select an appropriate
visualisation to demonstrate this
'''
# Out:
# '\n5. Determine if there is any significant correlation between the number of violations\ncommitted per vendor and their zip code, ‘Is there a tendency for facilities in\nspecific locations to have more violations?’. You will need to select an appropriate\nvisualisation to demonstrate this\n'

# %%
from scipy.interpolate import interp1d

inspections = pd.read_csv('Inspections.csv')
inspections['Zip Bin'] = np.floor(inspections['Zip Codes']/100)*100
zipvio = inspections[['FACILITY NAME','Zip Bin']].value_counts().groupby('Zip Bin').mean()
fig, ax = plt.subplots(figsize = (30, 5))
zipindex = [str(x) for x in zipvio.index]
x = np.arange(len(zipvio.index))
plt.xticks(x, zipindex, rotation='vertical')
ax.bar(zipindex, zipvio.values)

f2 = interp1d(x, zipvio.values, kind='cubic')
xnew = np.linspace(0, len(zipindex)-1, num=len(zipindex)*10, endpoint=True)

ax.plot(xnew, f2(xnew), '--', color = 'red')

# %%
inspections[['FACILITY NAME','Zip Bin']].value_counts().groupby('Zip Bin').mean()
# Out:
# Zip Bin
# 2400.0     4.963100
# 2800.0     5.327456
# 2900.0     5.136691
# 3200.0     5.564935
# 3300.0     4.560278
# 3600.0     5.329909
# 3700.0     4.740000
# 4000.0     3.941176
# 4200.0     5.263690
# 5900.0     3.454545
# 7500.0     5.035714
# 8400.0     5.591944
# 8800.0     5.366045
# 8900.0     5.043189
# 9300.0     4.720563
# 9700.0     4.534539
# 10100.0    4.998270
# 18500.0    5.248292
# 18900.0    5.115346
# 19300.0    5.331281
# 19700.0    5.405447
# 20100.0    5.426614
# 22300.0    3.703704
# 22700.0    4.577528
# 23000.0    4.744530
# 23400.0    4.874106
# 23600.0    4.942240
# 24000.0    4.735835
# 24300.0    4.907510
# 24600.0    4.860717
# 25000.0    4.877540
# 25400.0    4.604087
# 25700.0    4.824377
# 26300.0    4.969935
# 26900.0    4.712644
# 27300.0    4.474806
# dtype: float64

# %%
test = inspections[['FACILITY NAME','Zip Bin']][inspections['Zip Bin']==2400.0]

# %%
inspections_sample.to_csv('inspections_sample.csv', index=False)

# %%
import os 
def find_csv_files(path):
    # Check for csvs in path
    filenames = os.listdir(path)
    csv_files = [x for x in filenames if x.endswith('.csv')]
    return csv_files


cwd = os.getcwd()
find_csv_files(cwd)
# Out:
# ['Inspections.csv', 'Inventroy.csv', 'violations.csv']

# %%
os.getcwd()
# Out:
# '/Users/tarek.lel/Desktop/uni/advanced-programming/formative-assignment/DataSet1'
